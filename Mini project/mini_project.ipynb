# %%
# Data analysis
# 0.Import the libaries
# 1.Load the Data
# 2.Check the data and understand
# 3.Preprocess the data
# 4.Explore the data
# 5.Visualize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.express as px

# %%
df=pd.read_csv('netflix.csv',index_col=0)
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
msno.matrix(df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
df.describe(exclude=np.number)
# Out:
#          type                 title       director                cast  \
# count    8807                  8807           6173                7982
# unique      2                  8807           4528                7692
# top     Movie  Dick Johnson Is Dead  Rajiv Chilaka  David Attenborough
# freq     6131                     1             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# ...

# %%
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
movie = df[df['type'] == 'Movie']
tv_show = df[df['type'] == 'TV Show']

# %%
movie.head()
# Out:
#           type                             title  \
# show_id
# s1       Movie              Dick Johnson Is Dead
# s7       Movie  My Little Pony: A New Generation
# s8       Movie                           Sankofa
# s10      Movie                      The Starling
# s13      Movie                      Je Suis Karl
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s10                     Theodore Melfi
# s13                Christian Schwochow
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
# ...

# %%
tv_show.head()
# Out:
#             type                  title         director  \
# show_id
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
#
#                                                       cast       country  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# s4                                                     NaN           NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_countries = pd.DataFrame(df.country.value_counts().reset_index().values, columns=["country", "count"])
df_countries.head(n=10)
# Out:
#           country count
# 0   United States  2818
# 1           India   972
# 2  United Kingdom   419
# 3           Japan   245
# 4     South Korea   199
# 5          Canada   181
# 6           Spain   145
# 7          France   124
# 8          Mexico   110
# 9           Egypt   106

# %%
px.bar(df_countries.head(10), 'country', 'count',title="top 10 countries with movie release", log_y=True)

# %%
data = dict(
    number=[2818,972,419,245,199,181,145,124,110,106],
    country=["United States", "India", "United Kingdom", "Canada", "Spain",'Turkey','Philippines','France','South Korea','Australia'])
fig = px.funnel(data, x='number', y='country',title="top 10 countries with movie release",)
fig.show()

# %%
fig = px.choropleth(   #distribution of content on basis of countries
    locationmode='country names',
    locations=df_countries.country,
    labels=df_countries["count"]
)
fig.show()

# %%
df[df_countries,['release_year'].plot(kind="bar",color="Blue",figsize=(12,6))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Hp\OneDrive\Documents\digipodium_python\Mini project\mini_project.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hp/OneDrive/Documents/digipodium_python/Mini%20project/mini_project.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> df[df_countries,['release_year'].plot(kind="bar",color="Blue",figsize=(12,6))]
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
plt.figure(figsize=(12,6))
df[df["type"]=="TV Show"]["release_year"].value_counts()[:20].plot(kind="bar",color="Blue")
plt.title("Frequency of TV shows which were released in different years and are available on Netflix")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16488\3186140295.py:2: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
# Text(0.5, 1.0, 'Frequency of TV shows which were released in different years and are available on Netflix')

# %%
tv_release = tv_show["release_year"].value_counts().reset_index()
px.funnel_area(tv_release.head(15),'index', 'release_year')

# %%
df[df["type"]=="Movie"].plot(kind="hist",bins=20,edgecolor='red',color='green',figsize=(10,5),alpha=0.5,grid=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
movie.director.value_counts()
# Out:
# Rajiv Chilaka                 19
# Raúl Campos, Jan Suter        18
# Suhas Kadav                   16
# Marcus Raboy                  15
# Jay Karas                     14
#                               ..
# Dennis Rovira van Boekholt     1
# Naoto Amazutsumi               1
# Jenny Gage                     1
# Kaila York                     1
# Mozez Singh                    1
# Name: director, Length: 4354, dtype: int64

# %%
plt.figure(figsize=(12,6))
df[df["type"]=="Movie"]["listed_in"].value_counts()[:10].plot(kind="barh",color="orange")
plt.title("Top 10 Genres of Movies",size=18)
# Out:
# Text(0.5, 1.0, 'Top 10 Genres of Movies')

# %%
plt.figure(figsize=(12,6))
df[df["type"]=="TV Show"]["listed_in"].value_counts()[:10].plot(kind="barh",color="yellow")
plt.title("Top 10 Genres of TV Shows",size=18)
plt.show()

# %%
rating_counts=df["rating"].value_counts().reset_index()
px.bar(rating_counts, 'index', 'rating', title="ratings in netflix")

# %%
rating_counts
# Out:
#        index  rating
# 0      TV-MA    3207
# 1      TV-14    2160
# 2      TV-PG     863
# 3          R     799
# 4      PG-13     490
# 5      TV-Y7     334
# 6       TV-Y     307
# 7         PG     287
# 8       TV-G     220
# 9         NR      80
# 10         G      41
# 11  TV-Y7-FV       6
# 12     NC-17       3
# 13        UR       3
# 14    74 min       1
# 15    84 min       1
# 16    66 min       1

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
duration_count=df["duration"].value_counts().reset_index()
duration_count
# Out:
#          index  duration
# 0     1 Season      1793
# 1    2 Seasons       425
# 2    3 Seasons       199
# 3       90 min       152
# 4       94 min       146
# ..         ...       ...
# 215     16 min         1
# 216    186 min         1
# 217    193 min         1
# 218    189 min         1
# 219    191 min         1
#
# [220 rows x 2 columns]

# %%
px.bar(rating_counts,release_count,'index','release_year','rating','duration',title='Release with ratings',log_y=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Hp\OneDrive\Documents\digipodium_python\Mini project\mini_project.ipynb Cell 27 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hp/OneDrive/Documents/digipodium_python/Mini%20project/mini_project.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> px.bar(rating_counts,release_count,'index','release_year','rating','duration',title='Release with ratings',log_y=True)
#
# NameError: name 'release_count' is not defined

# %%
release_count=df['release_year'].value_counts().reset_index()
release_count
# Out:
#     index  release_year
# 0    2018          1147
# 1    2017          1032
# 2    2019          1030
# 3    2020           953
# 4    2016           902
# ..    ...           ...
# 69   1959             1
# 70   1925             1
# 71   1961             1
# 72   1947             1
# 73   1966             1
#
# [74 rows x 2 columns]

# %%
director_name=df['director'].value_counts().reset_index()
px.bar(director_name,'index','director',title="Directors",log_y=True)

# %%
df[['release_year'],director_name].plot(kind='box',title='Imogration Trend of Japan',figsize=(15,5),linewidth=2,color='green',marker='o')
plt.xlabel('director')
plt.ylabel('Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Hp\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Hp\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Hp\miniconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['release_year'],                                index  director
# 0                      Rajiv Chilaka        19
# 1             Raúl Campos, Jan Suter        18
# 2                       Marcus Raboy        16
# 3                        Suhas Kadav        16
# 4                          Jay Karas        14
# ...

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_n']=pd.to_datetime(df['release_year'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Hp\OneDrive\Documents\digipodium_python\Mini project\mini_project.ipynb Cell 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hp/OneDrive/Documents/digipodium_python/Mini%20project/mini_project.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df('date_n')
#
# TypeError: 'DataFrame' object is not callable
