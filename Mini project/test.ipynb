# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.express as px
from collections import Counter

# %%
df=pd.read_csv('netflix.csv',index_col=0)
df.head(2)
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show         Blood & Water              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                listed_in  \
# show_id
# s1                                         Documentaries
# s2       International TV Shows, TV Dramas, TV Mysteries
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# ...

# %%
movie=df['movie'] = df['type'] == 'Movie'
df['tv_show'] = df['type'] == 'TV Show'

# %%
plt.figure(figsize=(2,4))
sns.countplot(data=df ,x='type')
# Out:
# <AxesSubplot: xlabel='type', ylabel='count'>

# %% [markdown]
# df.head(2)

# %%
cnt= Counter()
for text in df['title' ].values:
    for word in text.split():
        cnt[word]+=1
cnt.most_common()
# Out:
# [('The', 1545),
#  ('of', 692),
#  ('the', 677),
#  ('in', 229),
#  ('and', 225),
#  ('A', 217),
#  ('&', 179),
#  ('to', 168),
#  ('Love', 149),
#  ('My', 143),
#  ('a', 135),
#  ('2', 104),
#  ('I', 94),
#  ('with', 87),
#  ('You', 77),
#  ('Christmas', 77),
#  ('Man', 76),
#  ('for', 75),
#  ('Story', 73),
#  ('Life', 71),
#  ('on', 68),
#  ('World', 65),
#  ('Little', 63),
#  ('-', 61),
#  ('One', 60),
#  ('Movie', 58),
#  ('Last', 57),
#  ('Time', 56),
#  ('In', 55),
#  ('Black', 53),
#  ('Me', 53),
#  ('American', 53),
#  ('Is', 51),
#  ('All', 50),
#  ('House', 49),
#  ('at', 47),
#  ('Day', 45),
#  ('Live', 45),
#  ('de', 44),
#  ('Super', 43),
#  ('Power', 43),
#  ('Up', 42),
#  ('Girl', 41),
#  ('We', 40),
#  ('City', 39),
#  ('El', 39),
#  ('New', 38),
#  ('Night', 38),
#  ('No', 38),
#  ('Your', 37),
#  ('from', 37),
#  ('Game', 36),
#  ('Family', 35),
#  ('War', 34),
#  ('High', 34),
#  ('Girls', 34),
#  ('What', 34),
#  ('It', 33),
#  ('King', 33),
#  ('Good', 33),
# ...

# %%
df['cast'].value_counts()
# Out:
# David Attenborough                                                                                                                                                                            19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                       14
# Samuel West                                                                                                                                                                                   10
# Jeff Dunham                                                                                                                                                                                    7
# David Spade, London Hughes, Fortune Feimster                                                                                                                                                   6
# ...

# %%
df['listed_in'].value_counts().head(10).plot(kind='bar',figsize=(20,5),color='green',title='top 10 most castings')
# Out:
# <AxesSubplot: title={'center': 'top 10 most castings'}>

# %%
df['cast'].value_counts().head()
# Out:
# David Attenborough                                                                         19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil    14
# Samuel West                                                                                10
# Jeff Dunham                                                                                 7
# David Spade, London Hughes, Fortune Feimster                                                6
# Name: cast, dtype: int64

# %%
df['cast'].value_counts().head(10).plot(kind='bar',figsize=(20,5),color='green',title='top 10 most castings')
# Out:
# <AxesSubplot: title={'center': 'top 10 most castings'}>
