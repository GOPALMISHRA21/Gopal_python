# %%
import numpy as np
import matplotlib.pyplot as plt

t=np.linspace(0,10,100)
flg=plt.figure(figsize=(20,5),facecolor='lightblue')
plt.plot(t,np.sin(t),'b-',label='sin(t)')
plt.plot(t,np.tan(t),'r--',label='tan(t)')
plt.legend()
plt.show()
