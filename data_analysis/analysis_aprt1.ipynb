# %%
# Data analysis
# 0.Import the libaries
# 1.Load the Data
# 2.Check the data and understand
# 3.Preprocess the data
# 4.Explore the data
# 5.Visualize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datasets/indian_cities.csv',index_col=0)

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df2=pd.read_excel('datasets/Book1.xlsx')

# %%
df2
# Out:
#      Students  Hindi  English  Maths  Science
# 0      Anchal     45       85     34       34
# 1   Divyanshi     90       34     96       96
# 2       Priya     59       39     65       67
# 3     Anshika     45       23     56       23
# 4      Nikita     67       67     34       67
# 5       Gopal     49       34     45       34
# 6       Ankit     38       84     38       54
# 7  Shubhankar     67       23     67       45

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df.head(n=10)
# Out:
#            City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1        Mumbai     Maharashtra    12442373          18414288       853
# 2         Delhi           Delhi    11034555          16314838       876
# 3     Bangalore       Karnataka     8443675           8499399       923
# 4     Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5     Ahmedabad         Gujarat     5577940           6352254       898
# 6       Chennai      Tamil Nadu     4646732           8696010       989
# 7       Kolkata     West Bengal     4496694          14112536       908
# 8         Surat         Gujarat     4467797           4585367       756
# 9          Pune     Maharashtra     3124458           5049968       948
# 10       Jaipur       Rajasthan     3046163           3046163       900
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# 4        83.26
# 5        88.29
# 6        90.18
# 7        86.31
# 8        87.89
# ...

# %%
df.tail()
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 494      89.33
# 495      80.56
# 496      80.71
# 497      85.72
# 498      85.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 1 to 498
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              498 non-null    object
#  1   State             498 non-null    object
#  2   Population        498 non-null    int64
#  3   Metro_Population  498 non-null    int64
#  4   Sexratio          498 non-null    int64
#  5   Literacy          498 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 27.2+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Students  8 non-null      object
#  1   Hindi     8 non-null      int64
#  2   English   8 non-null      int64
#  3   Maths     8 non-null      int64
#  4   Science   8 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 448.0+ bytes

# %%
df2.describe()
# Out:
#           Hindi   English      Maths    Science
# count   8.00000   8.00000   8.000000   8.000000
# mean   57.50000  48.62500  54.375000  52.500000
# std    16.91998  26.03809  21.360427  23.682423
# min    38.00000  23.00000  34.000000  23.000000
# 25%    45.00000  31.25000  37.000000  34.000000
# 50%    54.00000  36.50000  50.500000  49.500000
# 75%    67.00000  71.25000  65.500000  67.000000
# max    90.00000  85.00000  96.000000  96.000000

# %%
df.describe()
# Out:
#          Population  Metro_Population     Sexratio    Literacy
# count  4.980000e+02      4.980000e+02   498.000000  498.000000
# mean   4.498030e+05      5.556033e+05   932.903614   84.261004
# std    1.029319e+06      1.501008e+06    55.392315    6.306394
# min    9.891600e+04      9.891600e+04   709.000000   48.280000
# 25%    1.256420e+05      1.384625e+05   894.250000   80.945000
# 50%    1.841050e+05      2.048060e+05   925.000000   85.180000
# 75%    3.495960e+05      4.103862e+05   975.500000   88.612500
# max    1.244237e+07      1.841429e+07  1093.000000   98.360000

# %%
df.describe(exclude=np.number)
# Out:
#               City          State
# count          498            498
# unique         497             30
# top     Aurangabad  Uttar Pradesh
# freq             2             64

# %%
df.describe(include='all')
# Out:
#               City          State    Population  Metro_Population  \
# count          498            498  4.980000e+02      4.980000e+02
# unique         497             30           NaN               NaN
# top     Aurangabad  Uttar Pradesh           NaN               NaN
# freq             2             64           NaN               NaN
# mean           NaN            NaN  4.498030e+05      5.556033e+05
# std            NaN            NaN  1.029319e+06      1.501008e+06
# min            NaN            NaN  9.891600e+04      9.891600e+04
# 25%            NaN            NaN  1.256420e+05      1.384625e+05
# 50%            NaN            NaN  1.841050e+05      2.048060e+05
# 75%            NaN            NaN  3.495960e+05      4.103862e+05
# max            NaN            NaN  1.244237e+07      1.841429e+07
#
#            Sexratio    Literacy
# count    498.000000  498.000000
# unique          NaN         NaN
# top             NaN         NaN
# freq            NaN         NaN
# ...

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df.isnull().sum()
# Out:
# City                0
# State               0
# Population          0
# Metro_Population    0
# Sexratio            0
# Literacy            0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Students', 'Hindi', 'English', 'Maths', 'Science'], dtype='object')

# %%
df2['Total']=df2['English'] + df2['Hindi'] + df2['Maths'] + df2['Science']
df2
# Out:
#      Students  Hindi  English  Maths  Science  Total
# 0      Anchal     45       85     34       34    198
# 1   Divyanshi     90       34     96       96    316
# 2       Priya     59       39     65       67    230
# 3     Anshika     45       23     56       23    147
# 4      Nikita     67       67     34       67    235
# 5       Gopal     49       34     45       34    162
# 6       Ankit     38       84     38       54    214
# 7  Shubhankar     67       23     67       45    202

# %%
df2['Total'].plot(kind='bar',figsize=(15,5))
# Out:
# <AxesSubplot: >

# %% [markdown]
# # dataframe reading and selecting subsets of data
# -row wise selection
#   -'df.lock[]'
#   -'df.ilock[]'
#   -'df.head()
#   -'df.tail()

# %%
df
# Out:
#             City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1         Mumbai     Maharashtra    12442373          18414288       853
# 2          Delhi           Delhi    11034555          16314838       876
# 3      Bangalore       Karnataka     8443675           8499399       923
# 4      Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5      Ahmedabad         Gujarat     5577940           6352254       898
# ...          ...             ...         ...               ...       ...
# 494      Gangtok          Sikkim      100286            100286       912
# 495        Datia  Madhya Pradesh      100284            100284       900
# 496        Nagda  Madhya Pradesh      100039            100039       947
# 497     Banswara       Rajasthan       99969            101177       960
# 498   Kapurthala          Punjab       98916             98916       839
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# ...

# %%
df.loc[100]   # specific row, as a series
# Out:
# City                 Maheshtala
# State               West Bengal
# Population               448317
# Metro_Population         448317
# Sexratio                    952
# Literacy                  82.03
# Name: 100, dtype: object

# %%
df.loc[100:120]   # multiple rows,as a series
# Out:
#                    City           State  Population  Metro_Population  \
# Rank
# 100          Maheshtala     West Bengal      448317            448317
# 101            Tiruppur      Tamil Nadu      444352            962982
# 102          Davanagere       Karnataka      434971            434971
# 103           Kozhikode          Kerala      431560           2030519
# 104             Kurnool  Andhra Pradesh      430214            478124
# 105               Akola     Maharashtra      425817            425817
# 106     Rajpur Sonarpur     West Bengal      424368            424368
# 107        Bokaro Steel       Jharkhand      414820            563417
# 108             Bellary       Karnataka      410445            410445
# 109             Patiala          Punjab      406192            445196
# 110       South Dum Dum     West Bengal      403316            403316
# 111   Rajarhat Gopalpur     West Bengal      402844            402844
# ...

# %%
df.loc[[51,101,201,301]]  # multiple rows ina list style
# Out:
#             City          State  Population  Metro_Population  Sexratio  \
# Rank
# 51      Bareilly  Uttar Pradesh      903668            979933       895
# 101     Tiruppur     Tamil Nadu      444352            962982       955
# 201     Uluberia    West Bengal      222240            222240       951
# 301   Dallo Pura          Delhi      154791            154791       905
#
#       Literacy
# Rank
# 51       68.25
# 101      87.81
# 201      80.03
# 301      83.15

# %%
cities=[51,101,201,301,410]
cols=['City','Population']
df.loc[cities,cols]
# Out:
#             City  Population
# Rank
# 51      Bareilly      903668
# 101     Tiruppur      444352
# 201     Uluberia      222240
# 301   Dallo Pura      154791
# 410        Baran      117992

# %%
df.loc[[51,101,201,301,401],['City','Population']]   # same as above
# Out:
#             City  Population
# Rank
# 51      Bareilly      903668
# 101     Tiruppur      444352
# 201     Uluberia      222240
# 301   Dallo Pura      154791
# 401    Darjiling      118805

# %%
df.loc[:10]
# Out:
#            City           State  Population  Metro_Population  Sexratio  \
# Rank
# 1        Mumbai     Maharashtra    12442373          18414288       853
# 2         Delhi           Delhi    11034555          16314838       876
# 3     Bangalore       Karnataka     8443675           8499399       923
# 4     Hyderabad  Andhra Pradesh     6731790           7749334       955
# 5     Ahmedabad         Gujarat     5577940           6352254       898
# 6       Chennai      Tamil Nadu     4646732           8696010       989
# 7       Kolkata     West Bengal     4496694          14112536       908
# 8         Surat         Gujarat     4467797           4585367       756
# 9          Pune     Maharashtra     3124458           5049968       948
# 10       Jaipur       Rajasthan     3046163           3046163       900
#
#       Literacy
# Rank
# 1        89.73
# 2        87.59
# 3        88.71
# 4        83.26
# 5        88.29
# 6        90.18
# 7        86.31
# 8        87.89
# ...

# %%
df.iloc[10:20]
# Out:
#                       City           State  Population  Metro_Population  \
# Rank
# 11                 Lucknow   Uttar Pradesh     2817105           2901474
# 12                  Kanpur   Uttar Pradesh     2765348           2920067
# 13                  Nagpur     Maharashtra     2405665           2497777
# 14                  Indore  Madhya Pradesh     1964086           2167447
# 15                   Thane     Maharashtra     1841488           1841488
# 16                  Bhopal  Madhya Pradesh     1798218           1883381
# 17           Visakhapatnam  Andhra Pradesh     1728128           1728128
# 18    Pimpri and Chinchwad     Maharashtra     1727692           1727692
# 19                   Patna           Bihar     1684222           2046652
# 20                Vadodara         Gujarat     1670806           1817191
#
#       Sexratio  Literacy
# Rank
# 11         928     82.50
# 12         857     82.42
# 13         963     91.92
# 14         925     85.87
# ...

# %%
df2.iloc[-1]
# Out:
# Students    Shubhankar
# Hindi               67
# English             23
# Maths               67
# Science             45
# Total              202
# Name: 7, dtype: object

# %%
df2['Students']   # single column as a series
# Out:
# 0        Anchal
# 1     Divyanshi
# 2         Priya
# 3       Anshika
# 4        Nikita
# 5         Gopal
# 6         Ankit
# 7    Shubhankar
# Name: Students, dtype: object

# %%
df2['Hindi']
# Out:
# 0    45
# 1    90
# 2    59
# 3    45
# 4    67
# 5    49
# 6    38
# 7    67
# Name: Hindi, dtype: int64

# %%
df['Population'].mean()
# Out:
# 449803.0080321285

# %%
cols=['State','Literacy','Population']    # data frame with multiple frame
df[cols]
# Out:
#                State  Literacy  Population
# Rank
# 1        Maharashtra     89.73    12442373
# 2              Delhi     87.59    11034555
# 3          Karnataka     88.71     8443675
# 4     Andhra Pradesh     83.26     6731790
# 5            Gujarat     88.29     5577940
# ...              ...       ...         ...
# 494           Sikkim     89.33      100286
# 495   Madhya Pradesh     80.56      100284
# 496   Madhya Pradesh     80.71      100039
# 497        Rajasthan     85.72       99969
# 498           Punjab     85.08       98916
#
# [498 rows x 3 columns]
