# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
reportdf=pd.read_excel('datasets/Book1.xlsx')

# %%
reportdf['Total']=reportdf["Hindi"] +reportdf['English'] + reportdf['Maths'] + reportdf['Science']

# %%
reportdf.columns.tolist()
# Out:
# ['Students', 'Hindi', 'English', 'Maths', 'Science', 'Total']

# %%
reportdf
# Out:
#      Students  Hindi  English  Maths  Science  Total
# 0      Anchal     45       85     34       34    198
# 1   Divyanshi     90       34     96       96    316
# 2       Priya     59       39     65       67    230
# 3     Anshika     45       23     56       23    147
# 4      Nikita     67       67     34       67    235
# 5       Gopal     49       34     45       34    162
# 6       Ankit     38       84     38       54    214
# 7  Shubhankar     67       23     67       45    202

# %%
reportdf['pct']=reportdf['Total']/400*100

# %%
reportdf
# Out:
#      Students  Hindi  English  Maths  Science  Total    pct
# 0      Anchal     45       85     34       34    198  49.50
# 1   Divyanshi     90       34     96       96    316  79.00
# 2       Priya     59       39     65       67    230  57.50
# 3     Anshika     45       23     56       23    147  36.75
# 4      Nikita     67       67     34       67    235  58.75
# 5       Gopal     49       34     45       34    162  40.50
# 6       Ankit     38       84     38       54    214  53.50
# 7  Shubhankar     67       23     67       45    202  50.50

# %%
print("Sum of students hindi marks =",reportdf['Hindi'].sum())
print("Mean of students hindi marks =",reportdf['Hindi'].mean())
print("Median of students hindi marks =",reportdf['Hindi'].median())
print("Standard Deviation of students hindi marks =",reportdf['Hindi'].std())
# Out:
# Sum of students hindi marks = 460
# Mean of students hindi marks = 57.5
# Median of students hindi marks = 54.0
# Standard Deviation of students hindi marks = 16.91997973656335

# %%
reportdf['Hindi'].plot()
# Out:
# <AxesSubplot: >

# %%
reportdf['Hindi'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
reportdf['Hindi'].plot(kind='hist',bins=20,edgecolor='red',color='green',figsize=(5,5),alpha=0.5,grid=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
reportdf[['Hindi','English']].plot(kind='hist',bins=20,edgecolor='red',color=['green','red'],figsize=(5,5),alpha=0.5,grid=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
reportdf[['Hindi','English']].plot(kind='hist',bins=20,edgecolor='red',color=['green','red'],figsize=(5,5),alpha=0.5,subplots=True)
plt.show()
